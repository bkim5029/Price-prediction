# %% [markdown]
# # Exploratory Data Analysis
# Steps of data analysis
# - summarize the main characteristics of data
# - uncover relationships between variables
# - extract important variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cleaned_car_data.csv')
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %% [markdown]
# # Finding out the Corrlation

# %% [markdown]
# `df.corr()` only gives correlated data with numeric value

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.139896          -0.029800    0.493203  0.608941
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# ...

# %%
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001250    0.566915
# stroke            -0.055390  1.000000           0.187854    0.098143
# compression-ratio  0.001250  0.187854           1.000000   -0.214489
# horsepower         0.566915  0.098143          -0.214489    1.000000

# %% [markdown]
# To find out the correlation between two numerical variable

# %%
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53834.1045827811)

# %%
df['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 196    16845
# 197    19045
# 198    21485
# 199    22470
# 200    22625
# Name: price, Length: 201, dtype: int64

# %%
df['engine-size']
# Out:
# 0      130
# 1      130
# 2      152
# 3      109
# 4      136
#       ...
# 196    141
# 197    141
# 198    173
# 199    145
# 200    141
# Name: engine-size, Length: 201, dtype: int64

# %% [markdown]
# As you can see corrlation value is above 0.87

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# # Descriptive Statistical Analysis

# %%
df.describe(include=['object'])
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count      201       201        201          201        201          201
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                201
# unique                 3
# top                  Low
# freq                 153

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
#creating dataframe
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
#renaming
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
#renaming index
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %% [markdown]
# # Grouping
# grouping data by different categories

# %% [markdown]
# group by the variable "drive-wheels". We see that there are 3 different categories of drive wheels

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# If we want to know, on average, which type of drive wheel is most valuable, we can group "drive-wheels" and then average them

# %%
df_group_one = df[['drive-wheels','price']]
df_group_one
# Out:
#     drive-wheels  price
# 0            rwd  13495
# 1            rwd  16500
# 2            rwd  16500
# 3            fwd  13950
# 4            4wd  17450
# ..           ...    ...
# 196          rwd  16845
# 197          rwd  19045
# 198          rwd  21485
# 199          rwd  22470
# 200          rwd  22625
#
# [201 rows x 2 columns]

# %% [markdown]
# calculate the average price for each of the different categories of data.

# %%
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# also grouping multiple variables

# %%
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# Creating pivot table using grouped data

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# fill the missing values with 0

# %%
grouped_pivot = grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# # Correlation and Causation
# - Correlation: measurement of the extent of interdependence between variables
# - Causation: relationship between cause and effect between two variables
#
# coefficent is a value measured in -1~1, -1 being negative correlation and 1 positive

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.139896          -0.029800    0.493203  0.608941
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# ...

# %% [markdown]
# ### P value
# P value is the probability value that the correlation between these two variables is significant.
# - p value of 0.05 means we are 95% confident that the correlation is significant
# - generally anything below 0.05 is what we are looking for

# %%
from scipy import stats

# %% [markdown]
# relationship between wheel-base and price

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])

# %%
pearson_coef
# Out:
# 0.584641822265508

# %%
p_value
# Out:
# 8.076488270733218e-20

# %% [markdown]
# For these stats, since the p-value is < 0.001, the correlation is significant however, the linear relationship isn't strong since the coefficent is only 0.58.

# %% [markdown]
# # ANOVA (Analysis of Variance)
# Anova test does not tell you the type of relationship that exists but only that relationship exists.
# - ANOVA is used to test whether there are significant differences between the means of two or more groups.
# - F value is calculated (Variation between group of data / Variation within its own data)
#
# <p><b>data1</b> = [13,43,24,48,20]
#
# <p><b>data2</b> = [12,42,21,45,21]
#
# - data1 has `High` variation within its group but `Low` variation between data2.
#
# <p><b>data3</b> = [1,2,3,5,6]
#
# <p><b>data4</b> = [10,11,13,14,15]
#
# - data3 has `Low` variation within its group but `High` variation between data4
#
# The main idea of ANOVA is to figure out how much total variance comes from
# - if most of the variation is `between groups(High F-value)`, the data does have a significant effect
# - if most of the variation is `within groups(Low F-value)`, the data does not have a significant effect
#
# <p><b>F-test score</b>: calculates how much the actual means deviate from the assumption, and reports it as the   F-test score. A larger score means there is a larger difference between the means which means we reject the null hypothesis.</p>
#
# `F = (Variance BETWEEN groups / Variance WITHIN groups)`
#
# <p><b>P-value</b>:  P-value tells how statistically significant our calculated score value is.</p>
#
# ### Large F value means there is a high probability that the groups do have different means meaning the data does make a difference (Rejecting Null Hypothesis)

# %%
grouped_test2 = df_gptest.groupby(['drive-wheels'])
grouped_test2.head(2)
# Out:
#     drive-wheels   body-style  price
# 0            rwd  convertible  13495
# 1            rwd  convertible  16500
# 3            fwd        sedan  13950
# 4            4wd        sedan  17450
# 5            fwd        sedan  15250
# 136          4wd    hatchback   7603

# %%
# only getting price for '4wd'
grouped_test2.get_group('4wd')['price']
# Out:
# 4      17450
# 136     7603
# 140     9233
# 141    11259
# 144     8013
# 145    11694
# 150     7898
# 151     8778
# Name: price, dtype: int64

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %% [markdown]
# examining only 2 groups

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23
